# %%
import sys
import os
import numpy as np
from sklearn import metrics
sys.path.append("..")
from SINC_functions import *

# %%
# import warnings
# warnings.filterwarnings("ignore",category = DeprecationWarning, module = user_ns.get("__name__"))

def TPR_FPR_B(phi,B):
    B_est = np.absolute(phi) > 0.050
    B_true = B != 0

    TP = np.sum(((phi > 0.50) == 1) & ((B != 0) == 1))  * 1.0
    FP = np.sum(((phi > 0.50) == 1) & ((B != 0) == 0))  * 1.0
    FN = np.sum(((phi > 0.50) == 0) & ((B != 0) == 1))  * 1.0
    TN = np.sum(((phi > 0.50) == 0) & ((B != 0) == 0))  * 1.0
    NN = np.sum(B_true == 0) * 1.0
    NP = np.sum(B_true == 1) * 1.0

    prec = TP / (TP + FP)
    recall = TP / (TP + FN)

    F1 = 2*(prec*recall) / (prec + recall)

    MCC = ((TP*TN) - (FP*FN))/np.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))

    TPR = TP/NP
    FPR = FP/(FP + NN)
    return(TPR,FPR,F1,MCC)

## get shapes for simulation
B_true = np.genfromtxt("./SimulatedData/Random/B1.csv")
X_true = np.genfromtxt("./SimulatedData/Random/x1.csv")[:,0:12]

N = X_true.shape[0]
P = X_true.shape[1]
Q = B_true.shape[1]


reps = 10
goal = .10
adj_est_all = np.zeros((P, P, reps))
EZ_all = np.zeros((P, P, reps))
B_est_all = np.zeros((P,Q,reps))
phi_all = np.copy(B_est_all)
spars = np.zeros(reps)
v0s = np.linspace(.0001, .01, reps)
TPR = np.zeros(reps)
FPR = np.zeros(reps)
from itertools import chain

results = np.zeros((25, 5))
results_B = np.zeros((25,4))
total_iters = np.zeros(reps)

Z_track_all = []
omega_track_all = []
B_track_all = []

for sim in range(2):
    TPR = np.zeros(reps)
    FPR = np.zeros(reps)
    iters = np.zeros(reps)
    spars = np.zeros(reps)
    
    v1 = 10
    lamb = 150
    vB = 1
    max_iters = 3
    tol_prec = 0.01
    tol_B = 0.01
    cpus = 1

    print("**********************start iteration " + str(sim) + "*************************")
    x = np.genfromtxt("./SimulatedData/Random/x" + str(2 + sim) + ".csv")
    m = np.genfromtxt("./SimulatedData/Random/m" + str(2 + sim) + ".csv")
    adj_true = np.genfromtxt("./SimulatedData/Random/adj" + str(2 + sim) + ".csv")
    adj_true = adj_true[0:12,0:12]
    B_true = np.genfromtxt("./SimulatedData/Random/B" + str(2 + sim) + ".csv")

    for v in range(reps):
        
        v0 = v0s[v]

        omega, EZ, phi,B,iters_total  = SINC(x[:,0:12], m, v0, v1, lamb, vB, max_iters, tol_prec, tol_B, cpus)
        
        B_est_all[:,:,v] = B
        phi_all[:,:,v] = phi
        EZ_all[:, :, v] = EZ
        adj_est = (EZ > 0.50)*1.0
        spars[v] = np.sum(adj_est) / 2
        TPR[v], FPR[v] = TPR_FPR(adj_true, adj_est)
        if np.sum(adj_est) / 2 <= 5:
            break

    adj_est_all = (EZ_all > 0.50) * 1
    ind = np.argmin(np.absolute((np.sum(adj_est_all, (0,1)) / (12 * 11 / 2.0) / 2) - .10))
    EZ = EZ_all[:, :, ind]
    phi_ind = phi_all[:,:,ind]
    total_iters[v] = iters[ind]


    TPR = np.append(1, np.append(TPR, 0))
    FPR = np.append(1, np.append(FPR, 0))
    auc = metrics.auc(np.array(FPR),np.array(TPR))

    auc_v0 = 0
    n = len(TPR)
    for n in range(n - 1):
        b1 = TPR[n]
        b2 = TPR[n + 1]
        h = FPR[n] - FPR[n + 1]
        auc_v0 += (b1 + b2) * h / 2

    adj_est = adj_est_all[:, :, ind]
    TPR, FPR = TPR_FPR(adj_true, adj_est)
    f1, mcc = F1(adj_true, adj_est)
    results[sim,] = [TPR, FPR, f1, mcc, auc]
    B_edges_true = (B_true[0:12,:] != 0)*1.0
    B_edges_est = (phi_ind > 0.50) *1
    results_B[sim,] = Performance_B(B_edges_true,B_edges_est)

    np.savetxt("./Results/NetworkResults_Random.csv",results, delimiter=",")
    np.savetxt("./Results/CoefficientResults_Random.csv",results_B, delimiter=",")
# Out:
# **********************start iteration 0*************************
# ('Finished Iteration 1: ', 'change in Omega,B,Z', 0.3482694426301354, 0.7258384020162496, 2.8098302940925413)
# ('Finished Iteration 2: ', 'change in Omega,B,Z', 0.4861332090381151, 0.18724169374260669, 1.0052113352762597)
# ('Finished Iteration 3: ', 'change in Omega,B,Z', 0.16414027716042412, 0.09112693686114903, 0.6213724144371198)
# ('v0 = ', 0.0001, 'Sparsity = ', 0.4444444444444444)
# ('Finished Iteration 1: ', 'change in Omega,B,Z', 0.33780211243921066, 0.7258384020162496, 2.8417640308186796)
# ('Finished Iteration 2: ', 'change in Omega,B,Z', 0.460597045328902, 0.18672557041407056, 1.0177969638095163)
# ('Finished Iteration 3: ', 'change in Omega,B,Z', 0.2161299770739432, 0.08847964186789409, 0.7005493324362746)
# ('v0 = ', 0.0012000000000000001, 'Sparsity = ', 0.3333333333333333)
# ('Finished Iteration 1: ', 'change in Omega,B,Z', 0.3296313079933927, 0.7258384020162496, 2.853277621878041)
# ('Finished Iteration 2: ', 'change in Omega,B,Z', 0.45560382989758197, 0.18548886058582448, 1.1650597772838505)
# ('Finished Iteration 3: ', 'change in Omega,B,Z', 0.17362188109479137, 0.08961592759845316, 0.5206786681246465)
# ('v0 = ', 0.0023, 'Sparsity = ', 0.2708333333333333)
# ('Finished Iteration 1: ', 'change in Omega,B,Z', 0.324466579048466, 0.7258384020162496, 2.85342959235589)
# ('Finished Iteration 2: ', 'change in Omega,B,Z', 0.45342540786611585, 0.18670798486141027, 1.2051991948953749)
# ('Finished Iteration 3: ', 'change in Omega,B,Z', 0.17836872737504827, 0.09015660641349155, 0.5280005614878536)
# ('v0 = ', 0.0034, 'Sparsity = ', 0.22916666666666666)
# ('Finished Iteration 1: ', 'change in Omega,B,Z', 0.3195882701423235, 0.7258384020162496, 2.8546115412372046)
# ('Finished Iteration 2: ', 'change in Omega,B,Z', 0.4494784514887237, 0.186831954172461, 1.242121979525729)
# ('Finished Iteration 3: ', 'change in Omega,B,Z', 0.185172673651387, 0.08708825395752695, 0.5306009487185603)
# ('v0 = ', 0.0045000000000000005, 'Sparsity = ', 0.1597222222222222)
# ('Finished Iteration 1: ', 'change in Omega,B,Z', 0.310707691844762, 0.7258384020162496, 2.8552276512962163)
# ('Finished Iteration 2: ', 'change in Omega,B,Z', 0.4471650037724335, 0.18699064027697054, 1.2309547850125875)
# ('Finished Iteration 3: ', 'change in Omega,B,Z', 0.1887700125142706, 0.08395856871758556, 0.5257945574369836)
# ('v0 = ', 0.005600000000000001, 'Sparsity = ', 0.0763888888888889)
# ('Finished Iteration 1: ', 'change in Omega,B,Z', 0.30650329692638545, 0.7258384020162496, 2.8568352339773204)
# ('Finished Iteration 2: ', 'change in Omega,B,Z', 0.44730405728005074, 0.1877210599662753, 1.2160888886838026)
# ('Finished Iteration 3: ', 'change in Omega,B,Z', 0.18861941672114857, 0.08403168774780456, 0.5178484895202033)
# ('v0 = ', 0.0067, 'Sparsity = ', 0.05555555555555555)
# ('Finished Iteration 1: ', 'change in Omega,B,Z', 0.29342129174899334, 0.7258384020162496, 2.8624604988978337)
# ('Finished Iteration 2: ', 'change in Omega,B,Z', 0.4523461401445096, 0.18772869212113907, 1.0762109743031512)
# ('Finished Iteration 3: ', 'change in Omega,B,Z', 0.18969531463461586, 0.0840604384528918, 0.491335482250439)
# ('v0 = ', 0.0078000000000000005, 'Sparsity = ', 0.04861111111111111)
# ('Finished Iteration 1: ', 'change in Omega,B,Z', 0.2872150060173272, 0.7258384020162496, 2.896706531135006)
# ('Finished Iteration 2: ', 'change in Omega,B,Z', 0.45360775669371534, 0.18727896215198647, 1.0107422107290995)
# ('Finished Iteration 3: ', 'change in Omega,B,Z', 0.1898693746433069, 0.08423629250384346, 0.49148036608060686)
# ('v0 = ', 0.0089, 'Sparsity = ', 0.041666666666666664)
# ('Finished Iteration 1: ', 'change in Omega,B,Z', 0.28673355865176386, 0.7258384020162496, 2.955672572487075)
# ('Finished Iteration 2: ', 'change in Omega,B,Z', 0.45434192752465785, 0.1871620594902209, 0.9604369298218853)
# ('Finished Iteration 3: ', 'change in Omega,B,Z', 0.1894178588841553, 0.08443557994023987, 0.49181895903765893)
# ('v0 = ', 0.01, 'Sparsity = ', 0.020833333333333332)
# **********************start iteration 1*************************
# ('Finished Iteration 1: ', 'change in Omega,B,Z', 0.27511950826694365, 0.7047647769922711, 3.7170901899539057)
# ('Finished Iteration 2: ', 'change in Omega,B,Z', 0.5330501721898444, 0.2510714104879853, 1.7297006607023353)
# ('Finished Iteration 3: ', 'change in Omega,B,Z', 0.22392219400100377, 0.15111062719149604, 1.4753950604153656)
# ('v0 = ', 0.0001, 'Sparsity = ', 0.4375)
# ('Finished Iteration 1: ', 'change in Omega,B,Z', 0.28025837142827525, 0.7047647769922711, 3.728005537878717)
# ('Finished Iteration 2: ', 'change in Omega,B,Z', 0.5231161311860958, 0.24234229359527992, 1.881941884987855)
# ('Finished Iteration 3: ', 'change in Omega,B,Z', 0.22780291783010476, 0.15418326908369157, 2.0019755009374283)
# ('v0 = ', 0.0012000000000000001, 'Sparsity = ', 0.3125)
# ('Finished Iteration 1: ', 'change in Omega,B,Z', 0.27925548611327355, 0.7047647769922711, 3.7284565018771563)
# ('Finished Iteration 2: ', 'change in Omega,B,Z', 0.5137674873549639, 0.239635191995219, 1.9022769654022234)
# ('Finished Iteration 3: ', 'change in Omega,B,Z', 0.22870934100076923, 0.15492909185010578, 1.9912221669705725)
# ('v0 = ', 0.0023, 'Sparsity = ', 0.24305555555555555)
# ('Finished Iteration 1: ', 'change in Omega,B,Z', 0.2778597853830995, 0.7047647769922711, 3.729062936354124)
# ('Finished Iteration 2: ', 'change in Omega,B,Z', 0.5061978651355454, 0.24247628919695285, 1.9164779939163794)
# ('Finished Iteration 3: ', 'change in Omega,B,Z', 0.2297229295583022, 0.1477767627818357, 1.462151009332087)
# ('v0 = ', 0.0034, 'Sparsity = ', 0.1527777777777778)
# ('Finished Iteration 1: ', 'change in Omega,B,Z', 0.2802832932607001, 0.7047647769922711, 3.7297113673461437)
# ('Finished Iteration 2: ', 'change in Omega,B,Z', 0.5054724934854301, 0.2410148387887593, 1.8858811775898818)
# ('Finished Iteration 3: ', 'change in Omega,B,Z', 0.22983023529102264, 0.1474858489979627, 1.5001554896150957)
# ('v0 = ', 0.0045000000000000005, 'Sparsity = ', 0.09722222222222222)
# ('Finished Iteration 1: ', 'change in Omega,B,Z', 0.28263749459506304, 0.7047647769922711, 3.730514390359149)
# ('Finished Iteration 2: ', 'change in Omega,B,Z', 0.5072804369992979, 0.2410043382867565, 1.885934075671384)
# ('Finished Iteration 3: ', 'change in Omega,B,Z', 0.2330700544690676, 0.1478852087618795, 2.0145654427181445)
# ('v0 = ', 0.005600000000000001, 'Sparsity = ', 0.05555555555555555)
# ('Finished Iteration 1: ', 'change in Omega,B,Z', 0.28260134834058737, 0.7047647769922711, 3.7307935021131478)
# ('Finished Iteration 2: ', 'change in Omega,B,Z', 0.5198358120288824, 0.24056463350521895, 1.884449838323976)
# ('Finished Iteration 3: ', 'change in Omega,B,Z', 0.23422966752607788, 0.14744195862556825, 2.01153798152925)
# ('v0 = ', 0.0067, 'Sparsity = ', 0.041666666666666664)
# ('Finished Iteration 1: ', 'change in Omega,B,Z', 0.2826892503491626, 0.7047647769922711, 3.730959885648671)
# ('Finished Iteration 2: ', 'change in Omega,B,Z', 0.5348876801244301, 0.23922265215161753, 1.880198117288601)
# ('Finished Iteration 3: ', 'change in Omega,B,Z', 0.23448508182641203, 0.14719020315575226, 1.9956806460849332)
# ('v0 = ', 0.0078000000000000005, 'Sparsity = ', 0.027777777777777776)
