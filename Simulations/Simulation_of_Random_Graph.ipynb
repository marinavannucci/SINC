# %%
import sys
import os
import numpy as np
from sklearn import metrics
sys.path.append("..")
from SINC_functions import *

# %%
# import warnings
# warnings.filterwarnings("ignore",category = DeprecationWarning, module = user_ns.get("__name__"))

def TPR_FPR_B(phi,B):
    B_est = np.absolute(phi) > 0.050
    B_true = B != 0

    TP = np.sum(((phi > 0.50) == 1) & ((B != 0) == 1))  * 1.0
    FP = np.sum(((phi > 0.50) == 1) & ((B != 0) == 0))  * 1.0
    FN = np.sum(((phi > 0.50) == 0) & ((B != 0) == 1))  * 1.0
    TN = np.sum(((phi > 0.50) == 0) & ((B != 0) == 0))  * 1.0
    NN = np.sum(B_true == 0) * 1.0
    NP = np.sum(B_true == 1) * 1.0

    prec = TP / (TP + FP)
    recall = TP / (TP + FN)

    F1 = 2*(prec*recall) / (prec + recall)

    MCC = ((TP*TN) - (FP*FN))/np.sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))

    TPR = TP/NP
    FPR = FP/(FP + NN)
    return(TPR,FPR,F1,MCC)

## get shapes for simulation
B_true = np.genfromtxt("./SimulatedData/Random/B1.csv")
X_true = np.genfromtxt("./SimulatedData/Random/x1.csv")[:,0:12]

N = X_true.shape[0]
P = X_true.shape[1]
Q = B_true.shape[1]


reps = 10
goal = .10
adj_est_all = np.zeros((P, P, reps))
EZ_all = np.zeros((P, P, reps))
B_est_all = np.zeros((P,Q,reps))
phi_all = np.copy(B_est_all)
spars = np.zeros(reps)
v0s = np.linspace(.0001, .01, reps)
TPR = np.zeros(reps)
FPR = np.zeros(reps)
from itertools import chain

groups = [[0] * 100]
groups = list(chain(*groups))
results = np.zeros((25, 6))
results_B = np.zeros((25,4))
total_iters = np.zeros(reps)

Z_track_all = []
omega_track_all = []
B_track_all = []

for sim in range(1):
    TPR = np.zeros(reps)
    FPR = np.zeros(reps)
    iters = np.zeros(reps)
    spars = np.zeros(reps)
    
    v1 = 10
    lamb = 150
    vB = 1
    max_iters = 50
    tol_prec = 0.01
    tol_B = 0.01
    cpus = 1

    print("**********************start iteration ********" + str(sim))
    x = np.genfromtxt("./SimulatedData/Random/x" + str(2 + sim) + ".csv")
    m = np.genfromtxt("./SimulatedData/Random/m" + str(2 + sim) + ".csv")
    adj_true = np.genfromtxt("./SimulatedData/Random/adj" + str(2 + sim) + ".csv")
    adj_true = adj_true[0:12,0:12]
    B_true = np.genfromtxt("./SimulatedData/Random/B" + str(2 + sim) + ".csv")

    for v in range(reps):
        
        v0 = v0s[v]

        omega, EZ, phi,B,iters_total  = SINC(x[:,0:12], m, v0, v1, lamb, vB, max_iters, tol_prec, tol_B, cpus)
        
        adj_est = (EZ > 0.50)*1
        
        adj_est_all[:, :, v] = adj_est
        B_est_all[:,:,v] = B
        phi_all[:,:,v] = phi
        EZ_all[:, :, v] = EZ
        spars[v] = np.sum(adj_est) / 2
        TPR[v], FPR[v] = TPR_FPR(adj_true, adj_est)
        if np.sum(adj_est) / 2 <= 5:
            break
# Out:
# **********************start iteration ********0
# ('Finished Iteration 1: ', 'change in Omega,B,Z', 0.3482694426301354, 0.7258384020162496, 2.8098302940925413)
# ('Finished Iteration 2: ', 'change in Omega,B,Z', 0.4861332090381151, 0.18724169374260669, 1.0052113352762597)
# ('Finished Iteration 3: ', 'change in Omega,B,Z', 0.16414027716042412, 0.09112693686114903, 0.6213724144371198)
# ('Finished Iteration 4: ', 'change in Omega,B,Z', 0.12949195889774157, 0.12854287870019626, 0.5948635994196635)
# ('Finished Iteration 5: ', 'change in Omega,B,Z', 0.061843081866014504, 0.12875390881791401, 0.5685747929505935)
# ('Finished Iteration 6: ', 'change in Omega,B,Z', 0.07032330272614651, 0.10576595883402948, 0.5154778948174186)
# ('Finished Iteration 7: ', 'change in Omega,B,Z', 0.027226913962561383, 0.09947728764617492, 0.2352927445949654)
# ('Finished Iteration 8: ', 'change in Omega,B,Z', 0.04306584460307006, 0.049187570038068174, 0.5016187859385022)
# ...

# %%
    ind = np.argmin(np.absolute((np.sum(np.sum(adj_est_all, 0), 0) / 2 / (100 * 99 / 2)) - .10))
    EZ = EZ_all[:, :, ind]
    phi_ind = phi_all[:,:,ind]
    total_iters[v] = iters[ind]


    TPR = np.append(1, np.append(TPR, 0))
    FPR = np.append(1, np.append(FPR, 0))
    auc = metrics.auc(np.array(FPR),np.array(TPR))

    auc_v0 = 0
    n = len(TPR)
    for n in range(n - 1):
        b1 = TPR[n]
        b2 = TPR[n + 1]
        h = FPR[n] - FPR[n + 1]
        auc_v0 += (b1 + b2) * h / 2

    adj_est = adj_est_all[:, :, ind]
    TPR, FPR = TPR_FPR(adj_true, adj_est)
    f1, mcc = F1(adj_true, adj_est)
    results[sim,] = [TPR, FPR, f1, mcc, auc, 0 ]
  #  print(phi_ind.shape)
   # results_B[sim,] = TPR_FPR_B(np.delete(phi_ind,0,axis = 0),B_true)
    B_edges_true = (B_true[0:12,:] != 0)*1
    B_edges_est = (phi_ind > 0.50) *1
    results_B[sim,] = Performance_B(B_edges_true,B_edges_est)
    print(results_B)
    print(results)

#     np.savetxt("/rsrch3/home/biostatistics/ntosborne/EM-MN/seadragon/Small_Sim/res/VI_network_5.csv",results, delimiter=",")
#     np.savetxt("/rsrch3/home/biostatistics/ntosborne/EM-MN/seadragon/Small_Sim/res/VI_B_5.csv",results_B, delimiter=",")
#     np.savetxt("/rsrch3/home/biostatistics/ntosborne/EM-MN/seadragon/Small_Sim/res/VI_iters_5.csv",total_iters, delimiter=",")

# %%
B_true.shape
